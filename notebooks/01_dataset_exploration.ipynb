# %%
from google.colab import drive

drive.mount("/content/drive")

# %%
from pathlib import Path

PROJECT_DRIVE = Path(
    "/content/drive/MyDrive/OUSL_MDMRDS"
)

RAW_DATA = PROJECT_DRIVE / "data" / "raw"
PROCESSED_DATA = PROJECT_DRIVE / "data" / "processed"
ANNOTATIONS = PROJECT_DRIVE / "data" / "annotations"
MODELS = PROJECT_DRIVE / "models"
CHECKPOINTS = PROJECT_DRIVE / "checkpoints"

for path in [
    RAW_DATA,
    PROCESSED_DATA,
    ANNOTATIONS,
    MODELS,
    CHECKPOINTS,
]:
    path.mkdir(parents=True, exist_ok=True)

print("Project directories ready.")
